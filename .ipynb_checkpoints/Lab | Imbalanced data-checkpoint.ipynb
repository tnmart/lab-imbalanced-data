# %% [markdown]
# # Lab | Imbalanced data

# %% [markdown]
# 1. Load the dataset and explore the variables.
# 2. We will try to predict variable Churn using a logistic regression on variables tenure, SeniorCitizen,MonthlyCharges.
# 3. Split the Dataset into X ('tenure', 'SeniorCitizen', 'MonthlyCharges') and y ('Churn')
# 4. Build the logistic regression model.
# 5. Evaluate the model.
# 6. Even a simple model will give us more than 70% accuracy. Why?
# 7. Synthetic Minority Oversampling TEchnique (SMOTE) is an over sampling technique based on nearest neighbors that adds new points between existing points. Apply imblearn.over_sampling.SMOTE to the dataset. Build and evaluate the logistic regression model. Is it there any improvement?

# %% [markdown]
# #### 1. Load the dataset and explore the variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
df = pd.read_csv('files_for_lab/customer_churn.csv')
display(df.head())
display(df.tail())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#checking for number of unique values
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
#checking for missing values
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#the column senior citizen seems to be categorical where 1 corresponds to true and 0 to False. I will then replace
#the values accordingly and change the data type of the column
df['SeniorCitizen'].replace({1: "True", 0: "False"}, inplace=True)

display(df.head())
display(df.tail())
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female         False     Yes         No       1           No
# 1  5575-GNVDE    Male         False      No         No      34          Yes
# 2  3668-QPYBK    Male         False      No         No       2          Yes
# 3  7795-CFOCW    Male         False      No         No      45           No
# 4  9237-HQITU  Female         False      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# 2. We will try to predict variable Churn using a logistic regression on variables tenure, SeniorCitizen,MonthlyCharges.
# 3. Split the Dataset into X ('tenure', 'SeniorCitizen', 'MonthlyCharges') and y ('Churn')

# %%
#X/y Split
X = df[['tenure', 'SeniorCitizen', 'MonthlyCharges']]
y = df['Churn']

# %%
#checking the correlation matrix for multicollinearity
correlations_matrix = X.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()
# Out:
# /var/folders/dx/5q4b9pnn4zl_g4hjsbv88qx00000gn/T/ipykernel_57946/3264983515.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations_matrix = X.corr()

# %% [markdown]
# There doesn't seem to exist multicollinearity between the X columns

# %%
#Train/test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
#Splitting X into categorical and numerical columns
X_train_num = X_train.select_dtypes(include = np.number)
X_test_num  = X_test.select_dtypes(include = np.number)

X_train_cat = X_train.select_dtypes('object')
X_test_cat  = X_test.select_dtypes('object')

display(X_train_num)
display(X_test_num)
display(X_train_cat)
display(X_test_cat)
# Out:
#       tenure  MonthlyCharges
# 3296      24           49.30
# 6397      54           65.25
# 6043       3           40.15
# 5309      61           20.25
# 3000      12           84.45
# ...      ...             ...
# 4931      15          103.45
# 3264      10           91.10
# 1653      58           20.75
# 2607       1           69.75
# 2732       4           20.40
#
# [5282 rows x 2 columns]
#       tenure  MonthlyCharges
# 2200      19           58.20
# 4627      60          116.60
# 3225      13           71.95
# 2828       1           20.45
# 3768      55           77.75
# ...      ...             ...
# 3184      71           83.30
# 2551      12           19.45
# 5735      48           20.00
# 5096      71           86.85
# 450       64           24.70
#
# [1761 rows x 2 columns]
#      SeniorCitizen
# 3296         False
# 6397          True
# 6043         False
# 5309         False
# 3000         False
# ...            ...
# 4931         False
# 3264         False
# ...

# %%
#applying MinMaxScaler to the numerical columns
from sklearn.preprocessing import MinMaxScaler

#fitting the train set
MinMaxScaler = MinMaxScaler()
transformer = MinMaxScaler.fit(X_train_num)

#Saving scaler
import pickle
import os

path = "scalers/"

isExist = os.path.exists(path)
if not isExist:
  os.makedirs(path)
  print("The new directory is created!")

filename = "MinMaxScaler.pkl"
with open(path+filename, "wb") as file:
    pickle.dump(MinMaxScaler, file)
# Out:
# The new directory is created!

# %%
#transforming the train and test sets
X_train_normalized = transformer.transform(X_train_num)
X_test_normalized  = transformer.transform(X_test_num)

#transforming the arrays into dataframes
X_train_norm = pd.DataFrame(X_train_normalized, columns=X_train_num.columns, index= X_train_num.index)
X_test_norm  = pd.DataFrame(X_test_normalized, columns=X_test_num.columns, index= X_test_num.index)

# %%
display(X_train_norm.shape)
display(X_test_norm.shape)
X_train_norm.describe().T
# Out:
# (5282, 2)
# (1761, 2)
#                  count      mean       std  min       25%       50%       75%  \
# tenure          5282.0  0.449196  0.340613  0.0  0.125000  0.402778  0.763889
# MonthlyCharges  5282.0  0.462802  0.298559  0.0  0.174303  0.518426  0.712649
#
#                 max
# tenure          1.0
# MonthlyCharges  1.0

# %%
# applying OneHotEncoder to the SeniorCitizen column
from sklearn.preprocessing import OneHotEncoder

#fitting on the train set
encoder = OneHotEncoder(drop='first')
encoder.fit(X_train_cat)

#saving encoder
path = "encoders/"

isExist = os.path.exists(path)
if not isExist:
  os.makedirs(path)
  print("The new directory is created!")

filename = "OneHotEncoder.pkl"
with open(path+filename, "wb") as file:
   pickle.dump(encoder, file)
# Out:
# The new directory is created!

# %%
#transforming both the train and test
X_train_cat_np = encoder.transform(X_train_cat).toarray()
X_test_cat_np  = encoder.transform(X_test_cat).toarray()

#converting to dataframes
X_train_cat = pd.DataFrame(X_train_cat_np, columns=encoder.get_feature_names_out(), 
                           index=X_train_cat.index)
X_test_cat = pd.DataFrame(X_test_cat_np,  columns=encoder.get_feature_names_out(),
                          index=X_test_cat.index)

# %%
display(X_train_cat)
display(X_test_cat)
# Out:
#       SeniorCitizen_True
# 3296                 0.0
# 6397                 1.0
# 6043                 0.0
# 5309                 0.0
# 3000                 0.0
# ...                  ...
# 4931                 0.0
# 3264                 0.0
# 1653                 0.0
# 2607                 1.0
# 2732                 0.0
#
# [5282 rows x 1 columns]
#       SeniorCitizen_True
# 2200                 0.0
# 4627                 0.0
# 3225                 0.0
# 2828                 0.0
# 3768                 0.0
# ...                  ...
# 3184                 0.0
# 2551                 0.0
# 5735                 0.0
# 5096                 0.0
# 450                  0.0
#
# [1761 rows x 1 columns]

# %%
#building X_train
X_train_transformed = pd.concat([X_train_norm, X_train_cat], axis=1)
X_train_transformed
# Out:
#         tenure  MonthlyCharges  SeniorCitizen_True
# 3296  0.333333        0.309263                 0.0
# 6397  0.750000        0.468127                 1.0
# 6043  0.041667        0.218127                 0.0
# 5309  0.847222        0.019920                 0.0
# 3000  0.166667        0.659363                 0.0
# ...        ...             ...                 ...
# 4931  0.208333        0.848606                 0.0
# 3264  0.138889        0.725598                 0.0
# 1653  0.805556        0.024900                 0.0
# 2607  0.013889        0.512948                 1.0
# 2732  0.055556        0.021414                 0.0
#
# [5282 rows x 3 columns]

# %%
#building X_test
X_test_transformed = pd.concat([X_test_norm, X_test_cat], axis=1)
X_test_transformed
# Out:
#         tenure  MonthlyCharges  SeniorCitizen_True
# 2200  0.263889        0.397908                 0.0
# 4627  0.833333        0.979582                 0.0
# 3225  0.180556        0.534861                 0.0
# 2828  0.013889        0.021912                 0.0
# 3768  0.763889        0.592629                 0.0
# ...        ...             ...                 ...
# 3184  0.986111        0.647908                 0.0
# 2551  0.166667        0.011952                 0.0
# 5735  0.666667        0.017430                 0.0
# 5096  0.986111        0.683267                 0.0
# 450   0.888889        0.064243                 0.0
#
# [1761 rows x 3 columns]

# %% [markdown]
# #### 4. Build the logistic regression model.

# %%
#creating logistic regression model
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')

lr.fit(X_train_transformed, y_train)

#saving model
path = "models/"
    
isExist = os.path.exists(path)
if not isExist:
    os.makedirs(path)
    print("The new directory is created!")

filename = "LogisticRegression.pkl" 
with open(path+filename, "wb") as file:
    pickle.dump(lr, file)

# %% [markdown]
# #### 5. Evaluate the model.

# %%
#evaluating the model using score metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score

y_pred_test = lr.predict(X_test_transformed)

print("The accuracy in the TEST set is: {:.2f}".format(accuracy_score(y_test,y_pred_test)))
print("The precision in the TEST set is: {:.2f}".format(precision_score(y_test,y_pred_test, pos_label='Yes')))
print("The recall in the TEST set is: {:.2f}".format(recall_score(y_test,y_pred_test, pos_label='Yes')))
print("The F1 in the TEST set is: {:.2f}".format(f1_score(y_test,y_pred_test, pos_label='Yes')))
print("The Kappa in the TEST set is: {:.2f}".format(cohen_kappa_score(y_test,y_pred_test)))
# Out:
# The accuracy in the TEST set is: 0.78
# The precision in the TEST set is: 0.61
# The recall in the TEST set is: 0.46
# The F1 in the TEST set is: 0.52
# The Kappa in the TEST set is: 0.39

# %%
#checking the Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm_test = confusion_matrix(y_test,y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=lr.classes_)
disp.plot()
plt.show()

# %% [markdown]
# #### 6. Even a simple model will give us more than 70% accuracy. Why?

# %%
count_churn = df['Churn'].value_counts()
print(count_churn)
sns.countplot(x = 'Churn', data = df);
plt.show()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# Answer: Since there is a really big class imbalance, the model can have a really high accuracy by simply predicting the majority class most of the time which is what happens in this case.

# %% [markdown]
# #### 7. Synthetic Minority Oversampling TEchnique (SMOTE) is an over sampling technique based on nearest neighbors that adds new points between existing points. Apply imblearn.over_sampling.SMOTE to the dataset. Build and evaluate the logistic regression model. Is it there any improvement?

# %%
#applying SMOTE
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=100,k_neighbors=3)

X_train_SMOTE,y_train_SMOTE = sm.fit_resample(X_train_transformed,y_train)

# %%
print(X_train.shape)
print(X_train_SMOTE.shape)
# Out:
# (5282, 3)
# (7752, 3)

# %%
y_train_SMOTE.value_counts()
# Out:
# No     3876
# Yes    3876
# Name: Churn, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_SMOTE, y_train_SMOTE)
y_pred_test = lr.predict(X_test_transformed)

print("The accuracy in the TEST set is: {:.2f}".format(accuracy_score(y_test,y_pred_test)))
print("The precision in the TEST set is: {:.2f}".format(precision_score(y_test,y_pred_test, pos_label='Yes')))
print("The recall in the TEST set is: {:.2f}".format(recall_score(y_test,y_pred_test, pos_label='Yes')))
print("The F1 in the TEST set is: {:.2f}".format(f1_score(y_test,y_pred_test, pos_label='Yes')))
print("The Kappa in the TEST set is: {:.2f}".format(cohen_kappa_score(y_test,y_pred_test)))

The accuracy in the TEST set is: 0.78
The precision in the TEST set is: 0.61
The recall in the TEST set is: 0.46
The F1 in the TEST set is: 0.52
The Kappa in the TEST set is: 0.39
# Out:
# The accuracy in the TEST set is: 0.72
# The precision in the TEST set is: 0.48
# The recall in the TEST set is: 0.72
# The F1 in the TEST set is: 0.58
# The Kappa in the TEST set is: 0.38

# %%
cm_test = confusion_matrix(y_test,y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=lr.classes_)
disp.plot()
plt.show()

# %% [markdown]
# Answer: Using the SMOTE technique we find the following relative to the first logistic regression model:
# - moderate decrease in accuracy and precision scores;
# - very small decrease in kappa score;
# - moderate increase in F1 score;
# - a relatively high increase in  recall score;
#
# The high increase in recall score is possibly due to the fact that the model is better at predicting the minority samples from y while the decrease in accuracy shows us that is not so good in predicting the majority sample.
